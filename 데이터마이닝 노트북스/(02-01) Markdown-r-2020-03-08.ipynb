# %% [markdown]
# ### 나혜석 / Na Hyeseok (1896 ~ 1948)
#
# 나혜석(羅蕙錫, 1896년 4월 28일 ~ 1948년 12월 10일)은 일제 강점기와 대한민국의 화가이자 작가, 시인, 조각가, 여성운동가, 사회운동가, 언론인이다.
#
# *Na Hye-sok (10 December 1896 and 1948, April 28, and 羅蕙錫) the Japanese colonial rule and the painter and writer, poet, sculptor of the Republic of Korea, women activists, social activists, journalists.*
#
# https://ko.wikipedia.org/wiki/%EB%82%98%ED%98%9C%EC%84%9D

# %% [markdown]
# ### **Connecting My Google Drive with Google Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### **Displaying Image from Various Sources**

# %%
from IPython.display import Image

# %%
#From Google Drive Storage
path="/content/gdrive/My Drive/데이터마이닝 노트북스/나혜석 (Google).png"
Image(path)

# %%
#From Website (Blog)
url="https://3.bp.blogspot.com/-muW_Dtj8zI0/WxdPLtwWoAI/AAAAAAAABeI/g9oqGOcFGd4RHuKzIietIcxS2_nH1gi-gCLcBGAs/s640/6.jpg"
Image(url)

# %%
#From Website (Instagram)
url="https://www.instagram.com/p/CEUIAr5DBeC/"
Image(url)

# %% [markdown]
# http://ilustracionesdeesteli.blogspot.com/
#
# Estelí Meza    “My Aunt Blossoms”
#
# Ahora su rostro resplandece.
#
# 이제 그의 얼굴이 빛난다
#
# Estelí Meza
#
# https://www.instagram.com/estelimeza/?hl=ko

# %% [markdown]
# # 마크다운
#
# 마크다운에 대해서 자세히 알아보시려면 다음 URL을 참조하시오.
#
# •http://daringfireball.net/projects/markdown/
#
# •http://en.wikipedia.org/wiki/Markdown

# %% [markdown]
# # Principles of Data Science (2016, Sinan Ozdemir)

# %% [markdown]
# # Types of Data

# %% [markdown]
# ## 수평선(Horizontal Rule): ***   ---   ___
#
# ***
#
#  • Structured versus unstructured data
#
#  • Quantitative versus qualitative data
#
#  • The four levels of data
#
# ---
#
# ___

# %% [markdown]
# ## 헤딩 태그
#
#
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6

# %% [markdown]
# ## 링크
#
# emoji 이모지
#
# https://steemit.com/steemkr-guide/@snow-airline/steemkr-quick-start-guide
#
# &#128525; &#128525; &#128525; &#128525; &#128525; &#128525; &#128525;
#
# &#128522; &#128522; &#128522; &#128522; &#128522; &#128522; &#128522;
#
# &#10024; &#10024; &#10024; &#10024; &#10024; &#10024; &#10024;

# %% [markdown]
# ## 인용문(Blockquotes)
#
# > **Structured versus unstructured data**
# >> The distinction between structured and unstructured data is usually the first question you want to ask yourself about the entire dataset. The answer to this question can mean the difference between needing three days or three weeks of time to perform a proper analysis.
# The basic breakdown is as follows (this is a rehashed definition of organized and unorganized data in the first chapter):
# >>> Structured (organized) data: This is data that can be thought of as observations and characteristics. It is usually organized using a table method (rows and columns).
# >>> Unstructured (unorganized) data: This data exists as a free entity and does not follow any standard organization hierarchy.

# %% [markdown]
# ## 이미지
#
# 이미지 링크인 경우 앞에 ! 만 추가하면 됨
#
# ![위키독스 로고](http://wikidocs.net/images/book/wikidocs.png)

# %% [markdown]
# ## René Magritte "Ceci n'est pas une pipe" "This is not a pipe".
#
# 《이미지의 배반》(La trahison des images)은 벨기에의 초현실주의 화가 르네 마그리트의 대표작이자 그의 세계를 이해하는 열쇠를 제공해주는 작품이다. 이 작품에는 흔한 파이프가 그려져 있지만 그 아래에는 'Ceci n'est pas une pipe'(이것은 파이프가 아니다)라고 쓰여 있다. 관습에 따르면 파이프를 재현한 그림 속의 파이프는 파이프가 맞지만, 마그리트는 관습적 사고방식을 깨기 위해 의도적으로 그림과 문장을 모순적으로 표현하였고 미술가가 대상을 매우 사실적으로 묘사한다 하더라도 그것은 그 대상의 재현일 뿐이지, 그 대상 자체일 수는 없다고 역설한다.
#
# 엄밀하게 말해서, 이것은 파이프가 아니고 파이프 그림이다. 그러나 말이란 간결하면서 명료해야 하는 바, 이 두 미덕 또는 조건은 다소 모순적이다. 그러므로 "이것은 파이프다"는 "이것은 파이프 그림이다"의 간결한 표현이라고 이해한다. 그러나 작가가 간결한 표현 요건을 무시했다고 단정하기는 어렵다. "이것은 파이프가 아니다"(1929)는 논리적으로 흠잡을 데 없는 "파이프 그림은 파이프 실물이 아니다"의 간결한 표현이기도 하다. 이것은 "지도는 영토가 아니다" (알프레드 코르집스키, 1933) 및 의미삼각형 (옥든 & 리차즈, 1923)과 같은 이론적 맥락이라고 믿어진다. 우리는 실물처럼 마음을 움직일 수 있는 그림과 글 등 상징에 너무 휘둘릴 수도 있다. 교육 훈련 뿐만 아니라 선전 선동 세뇌도 그런 경우다. 우상을 가리키며 "이것은 신이고, 따라서 우리는 이것에 우리 모든 것을 바쳐야 한다"면....
#
# The Treachery of Images (French: La Trahison des images) is a 1929 painting by surrealist painter René Magritte. It is also known as This is Not a Pipe and The Wind and the Song. Magritte painted it when he was 30 years old. It is on display at the Los Angeles County Museum of Art.
#
# The painting shows a pipe. Below it, Magritte painted, "Ceci n'est pas une pipe", French for "This is not a pipe".
#
# The famous pipe. How people reproached me for it! And yet, could you stuff my pipe? No, it's just a representation, is it not? So if I had written on my picture "This is a pipe", I'd have been lying!
#
# — René Magritte
#
# The theme of pipes with the text "Ceci n'est pas une pipe" is extended in Les Mots et Les Images, La Clé des Songes, Ceci n'est pas une pipe (L'air et la chanson), The Tune and Also the Words, Ceci n’est pas une pomme, and Les Deux Mystères.
#
# The painting is sometimes given as an example of meta message conveyed by paralanguage, like Alfred Korzybski's "The word is not the thing" and "The map is not the territory", as well as Denis Diderot's This is not a story. One interpretation is that the pipe in the painting is not a pipe, but rather a drawing of a pipe.
#
# On December 15, 1929, Paul Éluard and André Breton published an essay about poetry in La Révolution surréaliste (The Surrealist Revolution) as a reaction to the publication by poet Paul Valéry "Notes sur la poésie" in Les Nouvelles littéraires of September 28, 1929. When Valéry wrote "Poetry is a survival", Breton and Éluard made fun of it and wrote "Poetry is a pipe", as a reference to Magritte's painting.
#
# In the same edition of La Révolution surréaliste, Magritte published "Les mots et les images" (his founding text which illustrated where words play with images), his answer to the survey on love, and Je ne vois pas la [femme] cachée dans la forêt, a painting tableau surrounded by photos of sixteen surrealists with their eyes closed, including Magritte himself.
#
#
# https://en.wikipedia.org/wiki/The_Treachery_of_Images
#
#
# https://ko.wikipedia.org/wiki/%EC%9D%B4%EB%AF%B8%EC%A7%80%EC%9D%98_%EB%B0%B0%EB%B0%98
#
#
#
# ![alternative text][image]
#
# [image]: https://usonkrap.github.io/img/this_is_not_pipe.jpg "this is not pipe"

# %% [markdown]
# ## 문장 띄우기와 줄바꿈(Line Breaks), 강제개행
#
# 일반적으로 Markdown에서는 HTML 문법도 사용 가능하므로 <br></br>을 이용해서도 개행이 가능함

# %% [markdown]
# 세 개의 문장 끝에 연속적인 빈칸이 없음

# %% [markdown]
# The distinction between structured and unstructured data is usually the first question you want to ask yourself about the entire dataset.
# The answer to this question can mean the difference between needing three days or three weeks of time to perform a proper analysis.
# The basic breakdown is as follows (this is a rehashed definition of organized and unorganized data in the first chapter):

# %%
세 개의 문장 끝에 연속적인 빈칸이 있음, <br>태그도 사용 가능함

# %% [markdown]
# The distinction between structured and unstructured data is usually the first question you want to ask yourself about the entire dataset.
# The answer to this question can mean the difference between needing three days or three weeks of time to perform a proper analysis.
# The basic breakdown is as follows (this is a rehashed definition of organized and unorganized data in the first chapter):

# %% [markdown]
# 세 개의 문장 사이에 빈 줄이 하나씩 있음

# %% [markdown]
# The distinction between structured and unstructured data is usually the first question you want to ask yourself about the entire dataset.
#
# The answer to this question can mean the difference between needing three days or three weeks of time to perform a proper analysis.
#
# The basic breakdown is as follows (this is a rehashed definition of organized and unorganized data in the first chapter):

# %% [markdown]
# 각 문장 사이 세 줄의 빈칸 간격을 둠

# %% [markdown]
# The distinction between structured and unstructured data is usually the first question you want to ask yourself about the entire dataset.<br></br><br></br><br></br>The answer to this question can mean the difference between needing three days or three weeks of time to perform a proper analysis.<br></br><br></br><br></br>The basic breakdown is as follows (this is a rehashed definition of organized and unorganized data in the first chapter):

# %% [markdown]
# ## 리스트 만들기
#
# 리스트에는 두 가지 종류가 있음
#
#
# * 순차를 표시하는 리스트
#
# * 순차를 표시하지 않는 리스트
#
#
# 1. 순차를 표시하는 리스트
#
# 2. 순차를 표시하지 않는 리스트

# %% [markdown]
# ## 강조구문

# %% [markdown]
# ### 진하게  표시함 (Bold)
#
# 진하게 표시하고자 하는 단어 좌우에 별표 ** 를 삽입함
#
# **Structured (organized) data**: This is data that can be thought of as observations and characteristics. It is usually organized using a table method (rows and columns).

# %% [markdown]
# ### 기울여 표시함 (Italic)
#
# 기울여 표시하고자 하는 단어 좌우에 별표 `*` (또는`_`)를 삽입함
#
# *Structured (organized) data*: This is data that can be thought of as observations and characteristics. It is usually organized using a table method (rows and columns).
#
# _Structured (organized) data_: This is data that can be thought of as observations and characteristics. It is usually organized using a table method (rows and columns).

# %% [markdown]
# ### 진하고 기울여  표시함 (Bold and Italic)

# %% [markdown]
# 진하고 기울여 표시하고자 하는 단어 좌우에 `_**`와 `**_`를 삽입함
#
# _**Structured (organized) data**_: This is data that can be thought of as observations and characteristics. It is usually organized using a table method (rows and columns).

# %% [markdown]
# ## 취소선
#
# 물결 기호(~) 두개로 글자를 감싸면 적용됨
#
# HTML 문법으로는 `<del>` 태그를 이용하면 됨
#
#
# ~~취소선은 이런식으로 적용됩니다.~~

# %% [markdown]
# ## 스페이스 코드블록
#
# 삽입하는 코드 앞에 스페이스 4개를 삽입하면 됨 (모든줄에 스페이스 4개 삽입해야 함)
#
#     def sum(a, b):
#         return a+b

# %% [markdown]
# ## 인라인 코드블록
#
# 코드는 대부분 1줄이상으로 이루어져 있지만 짧막한 코드문장을 한 문장 내에 삽입하고 싶을 경우 코드 부분 좌우를 ```(back quote) 문자로 감싸면 됨
#
# 프로그램 수행 중 `return a+b` 라는 문장을 만나면 결과값이 반환됨

# %% [markdown]
# ## 인라인(inline) 강조: ``` (Grave)
#
# ## 블럭(block) 강조: `  ````
#
#
# ```
#  def sum(a, b):
#      return a+b
#  ```

# %% [markdown]
# ## 인라인 강조
#
#
# <div>
#   <br />
# </div>
#
#
#
# h1,h2,h3 {
#   color: red;
# }
#
#
#
# function func() {
#   var str = 'javascript';
#   return str;
# }
#
#
#
# s = "Python syntax highlighting"
# print s
#
#
#
# No language indicated, so no syntax highlighting in Markdown.
# But let's throw in a <b>tag</b>.

# %% [markdown]
# ## 테이블
#
# •헤더 셀을 구분 하기 위해서는 3개 이상의 -(dash)가 필요함
#
# •:(colon)으로 셀 내용을 정렬 할 수 있음
#
# •가장 바깥쪽 |(pipe)는 생략 가능함
#
#
#
# head1 | head2
# ------|-------
# hello | 헬로우
# hi    | 하이
#
#
#
#
# | 왼쪽 정렬 | 가운데 정렬 | 오른쪽 정렬 |
# | :----- | :-----: | -----: |
# | 내용 11 | 내용 12 | 내용 13 |
# | 내용 21 | 내용 22 | 내용 23 |

# %% [markdown]
# # <span style="color:blue"> <U> 데이터형 </U> </span>
#
#
# ## Built-in Data Types
#
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
#
# |  <center>Data Types</center> |  <center>Built-in</center> |
# |:--------|:--------|
# | Text Type | **str** |
# | Numeric Types | **int, float, complex** |
# | Sequence Types | **list, tuple, range** |
# | Mapping Type | **dict** |
# | Set Types | **set, frozenset** |
# | Boolean Type | **bool** |
# | Binary Types | **bytes, bytearray, memoryview** |
#
#
# You can get the data type of any object by using the <span style="color:red"> <U> type </U> </span>() function:
#
# In Python, the data type is set when you assign a value to a variable:
#
#
#
# ### 4가지 Scalar 타입
#
# * **int**: 정수형
#
# * **float**: 실수형
#
# * **None**: 값이 없음
#
# * **bool**: 논리값 (참(True), 거짓(False))

# %% [markdown]
# ### 칼라 조정
#
# <font color='magenta'><strong>Introduction to Data Science<strong></font>

# %% [markdown]
# ## 문서 내 목차 (Table Of Contents)
#
# 문서 내에 사용된 헤딩태그들을 이용하여 [TOC] 입력 시 그 부분에 목차가 자동으로 생성됨
#
# [TOC] 1.헤딩태그 [TOC] 2.인용구 [TOC] 3.리스트 1.순차표시 2.순차표시 없는 것 4.강조구문 1.진하게표시 (Bold) 2.기울여 표시 (Italic) 5.링크와 이미지 6.강제 줄 바꿈 7.코드블록 1.스페이스 코드블록 2.언어지정 코드블록 3.no-highlight 코드블록 4.인라인 코드블록 8.마크다운 extension 1.테이블 2.각주 3.문서 내 목차 (Table Of Contents) 9.위키독스 extension 1.팁 블록 [TOC]

# %% [markdown]
# ## 수식입력
#
# 수식의 좌우에 $$ 문자로 감싸주어야 함
#
# $$x = {-b \pm \sqrt{b^2-4ac} \over 2a}$$

# %% [markdown]
# ## inline 모드 수식입력
#
# inline 모드(같은줄에 표시)로 작성하고 싶으면 $$ 대신 $를 사용하면 됨
#
# 같은 줄에 표시하려면 $x = {-b \pm \sqrt{b^2-4ac} \over 2a}$에서 $를 수식의 좌우에 한개씩만 사용하여야 함

# %% [markdown]
# ## 행렬
#
#
# 긴 수평직선을 그리기 위해서는 '---' 표시함
#
# ---
#
# $ \begin{bmatrix}
# a & b  \\
# c & d
# \end{bmatrix}$
#
# ---

# %% [markdown]
# ## 각주
#
# 각주란 본문의 어떤 부분을 설명하거나 보충하기 위해 본문 아래쪽에 별도로 작성하는 간단한 설명문으로서 주로 내용의 출처를 밝힐 때 사용됨
#
#
# 파이썬에서 for 문은 C 나 파스칼에서 사용하던 것과 약간 다릅니다. <sup>[1](#footnote_1)</sup> (파스칼처럼) 항상 숫자의 산술적인 진행을 통해 반복하거나, (C처럼) 사용자가 반복 단계와 중지 조건을 정의할 수 있도록 하는 대신, 파이썬의 for 문은 임의의 시퀀스 (리스트나 문자열)의 항목들을 그 시퀀스에 들어있는 순서대로 반복합니다.
#
# for w in words[:]:  # Loop over a slice copy of the entire list.
#
# ...     if len(w) > 6:
#
# ...         words.insert(0, w)
#
# ...
#
# words
#
# ['defenestrate', 'cat', 'window', 'defenestrate']
#
# for w in words: 를 쓰면, 위의 예는 defenestrate 를 반복해서 넣고 또 넣음으로써, 무한한 리스트를 만들려고 시도하게 됩니다.
#
# <a name="footnote_1">1</a>: 루프 안에서 반복하는 시퀀스를 수정할 필요가 있다면 (예를 들어, 선택한 항목들을 중복시키기), 먼저 사본을 만들 것을 권합니다. 시퀀스를 반복할 때 묵시적으로 사본이 만들어지지는 않습니다. 슬라이스 표기법은 이럴 때 특히 편리합니다.

# %%
Heading
=======

Sub-heading
-----------

Paragraphs are separated
by a blank line.

Two spaces at the end of a line  
produces a line break.

Text attributes _italic_, 
**bold**, `monospace`.

Horizontal rule:

---

Strikethrough:
~~strikethrough~~

Bullet list:

  * apples
  * oranges
  * pears

Numbered list:

  1. lather
  2. rinse
  3. repeat

[Markdown 설명](http://en.wikipedia.org/wiki/Markdown).

![이미지](http://wikidocs.net/images/book/wikidocs.png)

> Markdown uses email-style > characters for blockquoting.

Inline <abbr title="Hypertext Markup Language">HTML</abbr> is supported.

# %% [markdown]
# Heading
# =======
#
# Sub-heading
# -----------
#
# Paragraphs are separated
# by a blank line.
#
# Two spaces at the end of a line
# produces a line break.
#
# Text attributes _italic_,
# **bold**, `monospace`.
#
# Horizontal rule:
#
# ---
#
# Strikethrough:
# ~~strikethrough~~
#
# Bullet list:
#
#   * apples
#   * oranges
#   * pears
#
# Numbered list:
#
#   1. lather
#   2. rinse
#   3. repeat
#
# [Markdown 설명](http://en.wikipedia.org/wiki/Markdown).
#
# ![이미지](http://wikidocs.net/images/book/wikidocs.png)
#
# > Markdown uses email-style > characters for blockquoting.
#
# Inline <abbr title="Hypertext Markup Language">HTML</abbr> is supported.
