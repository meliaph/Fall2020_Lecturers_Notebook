# %%
# !pip install -U dtale
# Out:
# Requirement already up-to-date: dtale in /usr/local/lib/python3.6/dist-packages (1.20.0)
# ...

# %%
import dtale
import dtale.app as dtale_app
import pandas as pd

# %%
dtale_app.USE_NGROK=True

# %%
df=pd.read_csv('/content/V7XJ9_10min.csv')

# %%
dtale.show(df)
# Out:
# http://a79c2b9448ad.ngrok.io/dtale/main/2
